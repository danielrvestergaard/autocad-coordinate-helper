# %%
import pyautogui
import time
import pyperclip
import numpy as np
import pandas as pd
import re
from pynput import mouse, keyboard
from ipywidgets import widgets
from tkinter import filedialog, Tk

from autocad_coordinate_helper import AutoCAD_Coordinate_Helper

# %%
hlpr = AutoCAD_ID_Helper()
